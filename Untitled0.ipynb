# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/'Colab Notebooks'/
# %ls -al
# %cd /content/drive/MyDrive/'Colab Notebooks'/test/
# Out:
# /content/drive/MyDrive/Colab Notebooks
# total 8
# drwx------ 2 root root 4096 Jul 15 10:05 .ipynb_checkpoints/
# drwx------ 3 root root 4096 Jul 15 12:34 test/
# /content/drive/MyDrive/Colab Notebooks/test

# %%
# !git remote rm origin

# %%
# !git remote -v
# Out:
# gmlwlsdl2	https://gmlwlsdl2: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@github.com/gmlwlsdl2/test.git (fetch)
# gmlwlsdl2	https://gmlwlsdl2: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@github.com/gmlwlsdl2/test.git (push)
# origin	https://gmlwlsdl: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@github.com/gmlwlsdl2/test.git (fetch)
# origin	https://gmlwlsdl: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@github.com/gmlwlsdl2/test.git (push)

# %%
# !git config user.email "heejin094@naver.com"
# !git config user.name "gmlwlsdl"

# %%
print("ha5")
# Out:
# ha5

# %%
# !git add .
# !git commit -m "gmlwlsdl2 3 commit"
# Out:
# [main 32c4940] gmlwlsdl2 3 commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Untitled0.ipynb (71%)

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 757 bytes | 94.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/gmlwlsdl2/test.git
#    0e472d3..32c4940  main -> main
