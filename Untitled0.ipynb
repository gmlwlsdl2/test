# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/'Colab Notebooks'/
# %ls -al
# %cd /content/drive/MyDrive/'Colab Notebooks'/test/
# Out:
# /content/drive/MyDrive/Colab Notebooks
# total 8
# drwx------ 2 root root 4096 Jul 15 10:05 .ipynb_checkpoints/
# drwx------ 3 root root 4096 Jul 15 12:34 test/
# /content/drive/MyDrive/Colab Notebooks/test

# %%
# !git remote rm origin

# %%
# !git remote -v
# Out:
# origin	https://gmlwlsdl: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@github.com/gmlwlsdl2/test.git (fetch)
# origin	https://gmlwlsdl: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@github.com/gmlwlsdl2/test.git (push)

# %%
# !git config user.email "heejin094@naver.com"
# !git config user.name "gmlwlsdl"

# %%
print("ha")
# Out:
# ha

# %%
# !git add .
# !git commit -m "gmlwlsdl2 commit"
# Out:
# [main (root-commit) d29a8f1] gmlwlsdl2 commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 Untitled0.ipynb

# %%
# !git push origin main
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 1.52 KiB | 120.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/gmlwlsdl2/test.git
#  * [new branch]      main -> main
