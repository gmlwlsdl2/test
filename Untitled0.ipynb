# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/'Colab Notebooks'/
# %ls -al
# %cd /content/drive/MyDrive/'Colab Notebooks'/test/
# Out:
# /content/drive/MyDrive/Colab Notebooks
# total 8
# drwx------ 2 root root 4096 Jul 15 10:05 .ipynb_checkpoints/
# drwx------ 3 root root 4096 Jul 15 12:34 test/
# /content/drive/MyDrive/Colab Notebooks/test

# %%
# Out:
# Cloning into 'test'...
# ...

# %%
# !git remote -v
# Out:
# origin	https://gmlwlsdl2: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@github.com/gmlwlsdl2/test.git (fetch)
# origin	https://gmlwlsdl2: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@github.com/gmlwlsdl2/test.git (push)

# %%
print("ha")
# Out:
# ha

# %%
# !git add .
# !git commit -m "gmlwlsdl2 commit"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@3b13eb8e2ffc.(none)')
