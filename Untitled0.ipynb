# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/'Colab Notebooks'/
# %ls -al
# %cd /content/drive/MyDrive/'Colab Notebooks'/test/
# Out:
# /content/drive/MyDrive/Colab Notebooks
# total 8
# drwx------ 2 root root 4096 Jul 15 10:05 .ipynb_checkpoints/
# drwx------ 3 root root 4096 Jul 15 12:34 test/
# /content/drive/MyDrive/Colab Notebooks/test

# %%
# !git remote add origin https://gmlwlsdl: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@github.com/gmlwlsdl2/test.git

# %%
# !git remote rm origin

# %%
# !git remote -v
# Out:
# origin	https://gmlwlsdl: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@github.com/gmlwlsdl2/test.git (fetch)
# origin	https://gmlwlsdl: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@github.com/gmlwlsdl2/test.git (push)

# %%
# !git config user.email "heejin094@gmail.com"
# !git config user.name "gmlwlsdl2"

# %%
print("ha3")
# Out:
# ha3

# %%
# !git add .
# !git commit -m "gmlwlsdl2 2 commit"
# Out:
# [main 40bfdda] gmlwlsdl2 2 commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Untitled0.ipynb (69%)

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 908 bytes | 90.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/gmlwlsdl2/test.git
#    116e17b..40bfdda  main -> main
